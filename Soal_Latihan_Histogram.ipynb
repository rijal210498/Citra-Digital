# %% [markdown]
# 1) Buatlah histogram dengan citra dengan data berikut ini.

# %% [raw]
# 120	129	122	121	125	130
# 124	128	125	123	129	129
# 127	123	122	128	121	125
# 122	126	124	127	139	120
# 128	128	123	120	129	121
# 128	127	124	122	121	126

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
 
plt.xlabel("awal")
    
awal = [120,129,122,121,125,130,
124,128,125,123,129,129,
127,123,122,128,121,125,
122,126,124,127,139,120,
128,128,123,120,129,121,
128,127,124,122,121,126
     ]

plt.hist(awal, bins=36,color=['green'],label=['rj'])
plt.legend()
plt.show()

# %%
plt.xlabel("Nilai")
plt.ylabel("Jumlah")
plt.title("Mencari Nilai Sk")

nrj = [3,4,4,3,3,3,2,3,5,4,1,1]
kj = [3,7,11,14,17,20,22,25,30,34,35,36]
sk  = [1,2,4,5,6,7,7,8,10,11,12,12]

plt.hist([nrj,kj,sk], bins=12, rwidth=1,  color=['green','orange','yellow'],label=['nrj','kj','sk'])
plt.legend()
plt.show()

# %%
plt.xlabel("Output Citra")
plt.ylabel("Jumlah")
plt.title("Mencari Nilai Output Citra")
    
output_citra1 = [1,11,4,2,7,12,
6,10,7,5,11,11,
8,5,4,10,2,7,
4,7,6,8,12,1,
10,10,5,1,11,2,
10,8,6,4,2,7,]

plt.hist(output_citra1, bins=36,color=['Black'],label=['Output Citra'])
plt.legend()
plt.show()

# %% [markdown]
# 2) Berikut ini terdapat potongan citra dengan ukuran 10x10 piksel dengan rentang nilai 0-7

# %% [raw]
# 7	7	7	7	7	5	5	5	5	5
# 7	7	7	6	6	6	6	5	5	5
# 5	5	5	5	5	4	4	5	5	5
# 3	3	3	3	4	4	4	4	5	6
# 4	4	4	2	2	0	0	0	0	1
# 5	5	6	7	7	7	7	6	6	7
# 4	4	3	3	4	5	5	5	6	6
# 7	7	7	7	7	6	7	7	7	5
# 6	6	6	6	7	7	7	5	5	5
# 4	4	4	5	5	5	6	6	6	6

# %%
plt.xlabel("Nilai Awal")
plt.ylabel("Jumlah")
plt.title("Mencari Nilai Nilai Awal")
    
awal2 = [7,7,7,7,7,5,5,5,5,5,
7,7,7,6,6,6,6,5,5,5,
5,5,5,5,5,4,4,5,5,5,
3,3,3,3,4,4,4,4,5,6,
4,4,4,2,2,0,0,0,0,1,
5,5,6,7,7,7,7,6,6,7,
4,4,3,3,4,5,5,5,6,6,
7,7,7,7,7,6,7,7,7,5,
6,6,6,6,7,7,7,5,5,5,
4,4,4,5,5,5,6,6,6,6]

plt.hist(awal2, bins=100,color=['Purple'],label=['Nilai  Awal'])
plt.legend()
plt.show()

# %% [markdown]
# a) Lakukanlah Histogram Equalization pada citra tersebut!
#
# b) Lakukanlah Histogram Specification pada citra tersebut dengan spesifikasi {0: 5%, 1:5%, 2:10%, 3:15%, 4:20%, 5:25%, 6:15%, 7:5%}!

# %% [markdown]
# Histogram Equalization

# %%
plt.xlabel("Nilai")
plt.ylabel("Jumlah")
plt.title("Mencari Nilai Sk")

nrj = [4,1,2,6,15,29,19,24]
kj = [4,5,7,13,28,57,76,100]
sk  = [0,0,0,1,2,4,5,7]

plt.hist([nrj,kj,sk], bins=8, rwidth=1,  color=['green','orange','yellow'],label=['nrj','kj','sk'])
plt.legend()
plt.show()

# %%
plt.xlabel("Output Citra")
plt.ylabel("Jumlah")
plt.title("Mencari Nilai Output Citra")
    
output_citra2 = [7,7,7,7,7,4,4,4,4,4,
7,7,7,5,5,5,5,4,4,4,
4,4,4,4,4,2,2,4,4,4,
1,1,1,1,2,2,2,2,4,5,
2,2,2,0,0,0,0,0,0,0,
4,4,5,7,7,7,7,5,5,7,
2,2,1,1,2,4,4,4,5,5,
7,7,7,7,7,5,7,7,7,4,
5,5,5,5,7,7,7,4,4,4,
2,2,2,4,4,4,5,5,5,5,]

plt.hist(output_citra2, bins=100,color=['Black'],label=['Output Citra'])
plt.legend()
plt.show()

# %% [markdown]
# Histogram Specification

# %%
plt.xlabel("Nilai")
plt.ylabel("Jumlah")
plt.title("Mencari Nilai Z")

px = [0.040,0.050,0.070,0.130,0.280,0.570,0.760,1.000]
pz = [0.05,0.10,0.20,0.35,0.55,0.80,0.95,1.00]
z  = [0,0,0,1,3,4,5,7]

plt.hist([px,pz,z], bins=8,color=['green','orange','yellow'],label=['px','pz','z'])
plt.legend()
plt.show()

# %%
plt.xlabel("Output Citra")
plt.ylabel("Jumlah")
plt.title("Mencari Nilai Output Citra")
    
output_citra2 = [7,7,7,7,7,4,4,4,4,4,
7,7,7,5,5,5,5,4,4,4,
4,4,4,4,4,3,3,4,4,4,
1,1,1,1,3,3,3,3,4,5,
3,3,3,0,0,0,0,0,0,0,
4,4,5,7,7,7,7,5,5,7,
3,3,1,1,3,4,4,4,5,5,
7,7,7,7,7,5,7,7,7,4,
5,5,5,5,7,7,7,4,4,4,
3,3,3,4,4,4,5,5,5,5,
]

plt.hist(output_citra2, bins=100,color=['Black'],label=['Output Citra'])
plt.legend()
plt.show()
