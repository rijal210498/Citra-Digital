# %% [markdown]
# # hasil awal

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

def main():
    
    path = "C:\\Users\\Rijal Muslim\\pcd uas\\Dataset\\"
    imgpath =  path + "4.2.07.tiff"
    img = cv2.imread(imgpath, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    
    k = np.array(([3, 0, 2],
                  [0, 2, 6], 
                  [6, 0, 2]), np.float32)
    
    print(k)
    

    output = cv2.filter2D(img, -1, k)
    
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Original Image')
    
    plt.subplot(1, 2, 2)
    plt.imshow(output)
    plt.title('Filtered Image')
    
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# [[3. 0. 2.]
#  [0. 2. 6.]
#  [6. 0. 2.]]

# %% [markdown]
# # KONVULUSI SHARPEN

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

def main():
    
    path = "C:\\Users\\Rijal Muslim\\pcd uas\\Dataset\\"
    imgpath =  path + "4.2.07.tiff"
    img = cv2.imread(imgpath, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    k = np.array(([0, -1, 0],
                  [-1, 5, -1], 
                  [0, -1, 0]), np.float32)
    
    print(k)
    

    output = cv2.filter2D(img, -1, k)
    
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Original Image')
    
    plt.subplot(1, 2, 2)
    plt.imshow(output)
    plt.title('Filtered Image')
    
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# [[ 0. -1.  0.]
#  [-1.  5. -1.]
#  [ 0. -1.  0.]]

# %% [markdown]
# # edge detection

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

def main():
    
    path = "C:\\Users\\Rijal Muslim\\pcd uas\\Dataset\\"
    imgpath =  path + "4.2.07.tiff"
    img = cv2.imread(imgpath, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    
   # k = np.array(np.ones((11, 11), np.float32))
    
    k = np.array(([1, 0, -1], [0, 0, -0], [0, -1, 0]), np.float32)
    
    print(k)
    

    output = cv2.filter2D(img, -1, k)
    
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Original Image')
    
    plt.subplot(1, 2, 2)
    plt.imshow(output)
    plt.title('Filtered Image')
    
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# [[ 1.  0. -1.]
#  [ 0.  0.  0.]
#  [ 0. -1.  0.]]

# %% [markdown]
# # Gaussian blur 3x3

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

def main():
    
    path = "C:\\Users\\Rijal Muslim\\pcd uas\\Dataset\\"
    imgpath =  path + "4.2.07.tiff"
    img = cv2.imread(imgpath, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    
   # k = np.array(np.ones((11, 11), np.float32))
    
    k = np.array(([1, 2, 1], 
                  [2, 4, 2], 
                  [1, 2, 1]), np.float32)/16
    
    print(k)
    

    output = cv2.filter2D(img, -1, k)
    
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Original Image')
    
    plt.subplot(1, 2, 2)
    plt.imshow(output)
    plt.title('Filtered Image')
    
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# [[0.0625 0.125  0.0625]
#  [0.125  0.25   0.125 ]
#  [0.0625 0.125  0.0625]]

# %% [markdown]
# # emboss

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

def main():
    
    path = "C:\\Users\\Rijal Muslim\\pcd uas\\Dataset\\"
    imgpath =  path + "4.2.07.tiff"
    img = cv2.imread(imgpath, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    
   # k = np.array(np.ones((11, 11), np.float32))
    
    k = np.array(([-2, 0, 0],
                  [0, 0, 0],
                  [0, 0, 2]), np.float32)
    
    print(k)
    

    output = cv2.filter2D(img, -1, k)
    
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Original Image')
    
    plt.subplot(1, 2, 2)
    plt.imshow(output)
    plt.title('Filtered Image')
    
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# [[-2.  0.  0.]
#  [ 0.  0.  0.]
#  [ 0.  0.  2.]]
